# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/admin/Downloads/zama.csv")

# %%
df
# Out:
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4     10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                 ...
# 6425      1131/1, 17th Cross, 7th Sector HSR, Bangalore
# 6426  445, Shop 1, 5th Main Road, Sector 6, HSR, Ban...
# 6427  2623, Next To Axis Bank, 27th Main Road, Secto...
# 6428  L139, 15th Cross, 5th Main, Sector 6, HSR Layo...
# 6429  1st Floor, BKL Building, Hosur Main Road, HSR,...
#
#                        name online_order book_table  rate  votes  \
# 0                     Jalsa          Yes        Yes   4.1    775
# 1            Spice Elephant          Yes         No   4.1    787
# 2           San Churro Cafe          Yes         No   3.8    918
# ...

# %%
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6430 entries, 0 to 6429
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      6430 non-null   object
#  1   name                         6430 non-null   object
#  2   online_order                 6430 non-null   object
#  3   book_table                   6430 non-null   object
#  4   rate                         6430 non-null   float64
#  5   votes                        6430 non-null   int64
#  6   location                     6430 non-null   object
#  7   rest_type                    6430 non-null   object
#  8   dish_liked                   3277 non-null   object
#  9   cuisines                     6430 non-null   object
#  10  approx_cost(for two people)  6430 non-null   object
#  11  menu_item                    6430 non-null   object
#  12  listed_in(type)              6430 non-null   object
# ...

# %%
df

# %%
import seaborn as sns
import matplotlib as plt

# %%
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
import seaborn as sns

# %%
online_order_counts = df['book_table'].value_counts()
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
sns.barplot(x=online_order_counts.index, y=online_order_counts.values,palette='rainbow')
plt.xlabel("book_table")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
online_order_counts = df['online_order'].value_counts()
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
sns.barplot(x=online_order_counts.index, y=online_order_counts.values,palette='rainbow')
plt.xlabel("Online Orders")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
location = df.groupby('location')['name'].nunique().reset_index()
most_names_location = location.loc[location['name'].idxmax()]
plt.figure(figsize=(10, 6))
plt.bar(location_name_counts['location'], location_name_counts['name'],)
plt.xlabel("Location")
plt.ylabel("Number of Restaurant Names")
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
cuisine_counts = df.groupby(['cuisines', 'name']).size().reset_index(name='count')

# Visualization
# You can create a bar plot to visualize the count of each cuisine for restaurant names.

# Sort the DataFrame by count in descending order
cuisine_counts_sorted = cuisine_counts.sort_values(by='count', ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(cuisine_counts_sorted['cuisines'], cuisine_counts_sorted['count'])
plt.xlabel("Cuisine")
plt.ylabel("Count")
plt.title("Count of Each Cuisine for Restaurant Names")
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['approx_cost(for two people)'].dropna().astype(float))
plt.ylabel("Approximate Cost for Two People")
plt.title("Distribution of Restaurant Costs")
plt.xticks([1], ['All Restaurants']) 
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='online_order',y='rate',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='book_table',y='rate',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='book_table', ylabel='rate'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='listed_in(type)',y='rate',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='listed_in(type)', ylabel='rate'>

# %%
plt.figure(figsize=(6,6))
sns.viloni(x='rating',y='rate',data=df,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[206], line 2
#       1 plt.figure(figsize=(6,6))
# ----> 2 sns.viloni(x='rating',y='rate',data=df,palette='rainbow')
#
# AttributeError: module 'seaborn' has no attribute 'viloni'

# %%
rest_type_counts = df['rest_type'].value_counts().reset_index()
rest_type_counts.columns = ['rest_type', 'count']

# Sort the DataFrame by count in descending order
rest_type_counts_sorted = rest_type_counts.sort_values(by='count', ascending=False)

# Visualization
# Create a bar plot to visualize the count of each "rest_type."

plt.figure(figsize=(12, 6))
plt.bar(rest_type_counts_sorted['rest_type'], rest_type_counts_sorted['count'], color='green')
plt.xlabel("Rest Type")
plt.ylabel("Count")
plt.title("Count of Each Rest Type in the Dataset")
plt.xticks(rotation=90)
plt.tight_layout()

# Show the bar plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[221], line 10
#       5 rest_type_counts_sorted = rest_type_counts.sort_values(by='count', ascending=False)
#       7 # Visualization
#       8 # Create a bar plot to visualize the count of each "rest_type."
# ---> 10 plt.figure(figsize=(12, 6))
#      11 plt.bar(rest_type_counts_sorted['rest_type'], rest_type_counts_sorted['count'], color='green')
#      12 plt.xlabel("Rest Type")
#
# TypeError: 'module' object is not callable

# %%
restaurant_types = df.groupby('name')['rest_type'].unique().reset_index()

# Display the mapping of 'restaurant' to 'rest_type'
print(restaurant_types)

# Visualization (optional)
# You can create a bar plot to visualize the number of restaurant types for each restaurant.
# This will show which restaurant has which types of rest_type.

# Calculate the number of restaurant types for each restaurant
restaurant_types['num_rest_types'] = restaurant_types['rest_type'].apply(len)

# Sort the DataFrame by the number of restaurant types
restaurant_types_sorted = restaurant_types.sort_values(by='num_rest_types', ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(restaurant_types_sorted['name'], restaurant_types_sorted['num_rest_types'])
plt.xlabel("Restaurant")
plt.ylabel("Number of Restaurant Types")
plt.title("Number of Restaurant Types for Each Restaurant")
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#                             name                rest_type
# 0      12th Main - Grand Mercure            [Fine Dining]
# 1                  1441 Pizzeria          [Casual Dining]
# 2             154 Breakfast Club                   [Cafe]
# 3              1722 Urban Bistro          [Casual Dining]
# 4                   20 Feet High     [Casual Dining, Bar]
# ...                          ...                      ...
# 2865               Zodiac Grills            [Quick Bites]
# 2866                      Zoey's                   [Cafe]
# 2867                  de Ranthal            [Quick Bites]
# 2868                     eat.fit  [Delivery, Quick Bites]
# 2869  i-Bar - The Park Bangalore                 [Lounge]
#
# [2870 rows x 2 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[226], line 17
# ...

# %%
df=pd.read_csv("C:/Users/admin/Downloads/zamatoo.csv")

# %%
df
# Out:
#                                                 address  \
# 0     155, 43rd Cross Road, 8th Block, Jayanagar, Ba...
# 1     1761, Near Swathi Nursing Home, 14th Main Road...
# 2     2, Old 36, 8th F Main, 3rd Block, Jayanagar, B...
# 3     1/4, Nisha Complex, KR Road, Near National Col...
# 4     412, 1st Cross, Vidyapeeta Road, 3rd Stage, Ba...
# ...                                                 ...
# 4971      1131/1, 17th Cross, 7th Sector HSR, Bangalore
# 4972  445, Shop 1, 5th Main Road, Sector 6, HSR, Ban...
# 4973  2623, Next To Axis Bank, 27th Main Road, Secto...
# 4974  L139, 15th Cross, 5th Main, Sector 6, HSR Layo...
# 4975  1st Floor, BKL Building, Hosur Main Road, HSR,...
#
#                        name online_order book_table  rate  votes  \
# 0        Sri Udupi Food Hub          Yes        Yes   4.1    175
# 1              Sagar Deluxe          Yes         No   3.2    167
# 2                   Grazers          Yes        Yes   3.9    291
# ...

# %%
rest_type_counts = df['rest_type'].value_counts()

# Plot the counts using a bar chart
plt.figure(figsize=(12, 6))
rest_type_counts.plot(kind='bar')
plt.title('Count of Each Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[234], line 4
#       1 rest_type_counts = df['rest_type'].value_counts()
#       3 # Plot the counts using a bar chart
# ----> 4 plt.figure(figsize=(12, 6))
#       5 rest_type_counts.plot(kind='bar')
#       6 plt.title('Count of Each Restaurant Type')
#
# TypeError: 'module' object is not callable

# %%
import pandas as pd

# %%
rest_type_counts = df['rest_type'].value_counts()

# Plot the counts using a bar chart
plt.figure(figsize=(12, 6))
rest_type_counts.plot(kind='bar')
plt.title('Count of Each Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[236], line 4
#       1 rest_type_counts = df['rest_type'].value_counts()
#       3 # Plot the counts using a bar chart
# ----> 4 plt.figure(figsize=(12, 6))
#       5 rest_type_counts.plot(kind='bar')
#       6 plt.title('Count of Each Restaurant Type')
#
# TypeError: 'module' object is not callable

# %%
import pandas  # Correct import of the pandas module

# %%
rest_type_counts = df['rest_type'].value_counts()
plt.figure(figsize=(12, 6))
rest_type_counts.plot(kind='bar')
plt.title('Count of Each Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Count')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
